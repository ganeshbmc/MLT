# %% [markdown]
# # Q2
#
# ## incomplete

# %%
import numpy as np

features = np.array([[-0.90912317, -1.64763394],
                     [-2.46713996, -0.40733471],
                     [-1.32169038, -3.06806195],
                     [3.05483814, 0.7044727],
                     [2.88645294, 2.89814917],
                     [2.73959279, 1.40490587]])

label = np.array([0, 0, 0, 1, 1, 1])

weight_vector = np.array([0.95183461, 0.11616577])

# %%
# loss = sum(((features @ weight_vector) - label)**2)
e = (features @ weight_vector) - label
loss = e.T @ e
loss
# Out:
# 20.899686450505044
